# %% [markdown]
# <a href="https://colab.research.google.com/github/RiccoFlores/100-Days-Of-ML-Code/blob/master/NB3_1_CasodeEstudio_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from numpy import nan
import matplotlib.pyplot as plt

# %%
diabetes_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv"
diabetes_dataframe = pd.read_csv(diabetes_url, header = None)

diabetes_dataframe.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
diabetes_dataframe.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
diabetes_dataframe.columns = ["pregnancies", "glucose", "pressure", "skin", "insulin", "bmi", "pedigree", "age", "target"]

# %%
diabetes_dataframe.head()
# Out:
#    pregnancies  glucose  pressure  skin  insulin   bmi  pedigree  age  target
# 0            6      148        72    35        0  33.6     0.627   50       1
# 1            1       85        66    29        0  26.6     0.351   31       0
# 2            8      183        64     0        0  23.3     0.672   32       1
# 3            1       89        66    23       94  28.1     0.167   21       0
# 4            0      137        40    35      168  43.1     2.288   33       1

# %% [markdown]
# Características
# * 0 Number of times pregnant.
# * 1 Plasma glucose concentration a 2 hours in an oral glucose tolerance test.
# * 2 Diastolic blood pressure (mm Hg).
# * 3 Triceps skinfold thickness (mm).
# * 4 2-Hour serum insulin (mu U/ml).
# * 5 Body mass index (weight in kg/(height in m)^2).
# * 6 Diabetes pedigree function.
# * 7 Age (years).
# * 8 Class variable (0 or 1).

# %%
# Data Size
diabetes_shape = diabetes_dataframe.shape
print(diabetes_shape)
print("Registros: ", diabetes_shape[0])
print("Columnas:", diabetes_shape[1])
# Out:
# (768, 9)
# Registros:  768
# Columnas: 9

# %%
diabetes_dataframe.isnull()
# Out:
#      pregnancies  glucose  pressure   skin  insulin    bmi  pedigree    age  \
# 0          False    False     False  False    False  False     False  False
# 1          False    False     False  False    False  False     False  False
# 2          False    False     False  False    False  False     False  False
# 3          False    False     False  False    False  False     False  False
# 4          False    False     False  False    False  False     False  False
# ..           ...      ...       ...    ...      ...    ...       ...    ...
# 763        False    False     False  False    False  False     False  False
# 764        False    False     False  False    False  False     False  False
# 765        False    False     False  False    False  False     False  False
# 766        False    False     False  False    False  False     False  False
# 767        False    False     False  False    False  False     False  False
#
#      target
# 0     False
# 1     False
# 2     False
# ...

# %%
diabetes_dataframe.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# pressure       0
# skin           0
# insulin        0
# bmi            0
# pedigree       0
# age            0
# target         0
# dtype: int64

# %%
diabetes_dataframe.describe()
# Out:
#        pregnancies     glucose    pressure        skin     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi    pedigree         age      target
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
diabetes_dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]] = diabetes_dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]].replace(0, nan)

# %%
diabetes_dataframe
# Out:
#      pregnancies  glucose  pressure  skin  insulin   bmi  pedigree  age  \
# 0              6    148.0      72.0  35.0      NaN  33.6     0.627   50
# 1              1     85.0      66.0  29.0      NaN  26.6     0.351   31
# 2              8    183.0      64.0   NaN      NaN  23.3     0.672   32
# 3              1     89.0      66.0  23.0     94.0  28.1     0.167   21
# 4              0    137.0      40.0  35.0    168.0  43.1     2.288   33
# ..           ...      ...       ...   ...      ...   ...       ...  ...
# 763           10    101.0      76.0  48.0    180.0  32.9     0.171   63
# 764            2    122.0      70.0  27.0      NaN  36.8     0.340   27
# 765            5    121.0      72.0  23.0    112.0  26.2     0.245   30
# 766            1    126.0      60.0   NaN      NaN  30.1     0.349   47
# 767            1     93.0      70.0  31.0      NaN  30.4     0.315   23
#
#      target
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# ...

# %%
#diabetes_dataframe.isnull().sum()
100 * diabetes_dataframe.isnull().sum() / diabetes_shape[0]
# Out:
# pregnancies     0.000000
# glucose         0.651042
# pressure        4.557292
# skin           29.557292
# insulin        48.697917
# bmi             1.432292
# pedigree        0.000000
# age             0.000000
# target          0.000000
# dtype: float64

# %%
#seaborn
for column in diabetes_dataframe.columns:
    diabetes_dataframe[column].plot(kind = "hist", title = column)
    plt.show()

# %% [markdown]
# ## Eliminación de Filas & Columnas

# %%
dataframe = diabetes_dataframe.copy()

# %%
#dataframe.shape
dataframe.head()
# Out:
#    pregnancies  glucose  pressure  skin  insulin   bmi  pedigree  age  target
# 0            6    148.0      72.0  35.0      NaN  33.6     0.627   50       1
# 1            1     85.0      66.0  29.0      NaN  26.6     0.351   31       0
# 2            8    183.0      64.0   NaN      NaN  23.3     0.672   32       1
# 3            1     89.0      66.0  23.0     94.0  28.1     0.167   21       0
# 4            0    137.0      40.0  35.0    168.0  43.1     2.288   33       1

# %%
dataframe_clean = dataframe.dropna(axis = 0)

# %%
dataframe_clean.shape
# Out:
# (392, 9)

# %%
dataframe.dropna(axis = 0, inplace = True)

# %%
# Data Size
diabetes_shape = dataframe.shape

print("Registros: ", diabetes_shape[0])
print("Columnas:", diabetes_shape[1])
# Out:
# Registros:  392
# Columnas: 9

# %%
dataframe.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# pressure       0
# skin           0
# insulin        0
# bmi            0
# pedigree       0
# age            0
# target         0
# dtype: int64

# %% [markdown]
# ## Simple Imputation (Zero)

# %%
dataframe = diabetes_dataframe.copy()

# %%
dataframe.shape
# Out:
# (768, 9)

# %%
dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]].replace(nan, 0, inplace = True)
# Out:
# <ipython-input-22-1dd341ff0fa7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]].replace(nan, 0, inplace = True)

# %%
dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]] = dataframe[["glucose", "pressure", "skin", "insulin", "bmi"]].replace(nan, 0)

# %%
dataframe.head()
# Out:
#    pregnancies  glucose  pressure  skin  insulin   bmi  pedigree  age  target
# 0            6    148.0      72.0  35.0      0.0  33.6     0.627   50       1
# 1            1     85.0      66.0  29.0      0.0  26.6     0.351   31       0
# 2            8    183.0      64.0   0.0      0.0  23.3     0.672   32       1
# 3            1     89.0      66.0  23.0     94.0  28.1     0.167   21       0
# 4            0    137.0      40.0  35.0    168.0  43.1     2.288   33       1

# %%
# Data Size
diabetes_shape = dataframe.shape

print("Registros: ", diabetes_shape[0])
print("Columnas:", diabetes_shape[1])
# Out:
# Registros:  768
# Columnas: 9

# %%
dataframe.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# pressure       0
# skin           0
# insulin        0
# bmi            0
# pedigree       0
# age            0
# target         0
# dtype: int64

# %% [markdown]
# ## Simple Imputation (Mean)

# %%
dataframe = diabetes_dataframe.copy()

# %%
dataframe.describe().T
# Out:
#              count        mean         std     min       25%       50%  \
# pregnancies  768.0    3.845052    3.369578   0.000   1.00000    3.0000
# glucose      763.0  121.686763   30.535641  44.000  99.00000  117.0000
# pressure     733.0   72.405184   12.382158  24.000  64.00000   72.0000
# skin         541.0   29.153420   10.476982   7.000  22.00000   29.0000
# insulin      394.0  155.548223  118.775855  14.000  76.25000  125.0000
# bmi          757.0   32.457464    6.924988  18.200  27.50000   32.3000
# pedigree     768.0    0.471876    0.331329   0.078   0.24375    0.3725
# age          768.0   33.240885   11.760232  21.000  24.00000   29.0000
# target       768.0    0.348958    0.476951   0.000   0.00000    0.0000
#
#                    75%     max
# pregnancies    6.00000   17.00
# glucose      141.00000  199.00
# pressure      80.00000  122.00
# skin          36.00000   99.00
# insulin      190.00000  846.00
# bmi           36.60000   67.10
# pedigree       0.62625    2.42
# ...

# %%
dataframe.mean()
# Out:
# pregnancies      3.845052
# glucose        121.686763
# pressure        72.405184
# skin            29.153420
# insulin        155.548223
# bmi             32.457464
# pedigree         0.471876
# age             33.240885
# target           0.348958
# dtype: float64

# %%
dataframe.fillna(dataframe.mean(), inplace=True)
#dataframe.fillna(method = 'ffill', inplace = True)
#dataframe.fillna(method = 'bfill', inplace = True)

# %%
dataframe.head()
# Out:
#    pregnancies  glucose  pressure      skin     insulin   bmi  pedigree  age  \
# 0            6    148.0      72.0  35.00000  155.548223  33.6     0.627   50
# 1            1     85.0      66.0  29.00000  155.548223  26.6     0.351   31
# 2            8    183.0      64.0  29.15342  155.548223  23.3     0.672   32
# 3            1     89.0      66.0  23.00000   94.000000  28.1     0.167   21
# 4            0    137.0      40.0  35.00000  168.000000  43.1     2.288   33
#
#    target
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1

# %%
# Data Size
diabetes_shape = dataframe.shape

print("Registros: ", diabetes_shape[0])
print("Columnas:", diabetes_shape[1])
# Out:
# Registros:  768
# Columnas: 9

# %%
dataframe.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# pressure       0
# skin           0
# insulin        0
# bmi            0
# pedigree       0
# age            0
# target         0
# dtype: int64

# %%
dataframe.describe().T
# Out:
#              count        mean        std     min        25%         50%  \
# pregnancies  768.0    3.845052   3.369578   0.000    1.00000    3.000000
# glucose      768.0  121.686763  30.435949  44.000   99.75000  117.000000
# pressure     768.0   72.405184  12.096346  24.000   64.00000   72.202592
# skin         768.0   29.153420   8.790942   7.000   25.00000   29.153420
# insulin      768.0  155.548223  85.021108  14.000  121.50000  155.548223
# bmi          768.0   32.457464   6.875151  18.200   27.50000   32.400000
# pedigree     768.0    0.471876   0.331329   0.078    0.24375    0.372500
# age          768.0   33.240885  11.760232  21.000   24.00000   29.000000
# target       768.0    0.348958   0.476951   0.000    0.00000    0.000000
#
#                     75%     max
# pregnancies    6.000000   17.00
# glucose      140.250000  199.00
# pressure      80.000000  122.00
# skin          32.000000   99.00
# insulin      155.548223  846.00
# bmi           36.600000   67.10
# ...

# %%
diabetes_dataframe.describe().T
# Out:
#              count        mean         std     min       25%       50%  \
# pregnancies  768.0    3.845052    3.369578   0.000   1.00000    3.0000
# glucose      763.0  121.686763   30.535641  44.000  99.00000  117.0000
# pressure     733.0   72.405184   12.382158  24.000  64.00000   72.0000
# skin         541.0   29.153420   10.476982   7.000  22.00000   29.0000
# insulin      394.0  155.548223  118.775855  14.000  76.25000  125.0000
# bmi          757.0   32.457464    6.924988  18.200  27.50000   32.3000
# pedigree     768.0    0.471876    0.331329   0.078   0.24375    0.3725
# age          768.0   33.240885   11.760232  21.000  24.00000   29.0000
# target       768.0    0.348958    0.476951   0.000   0.00000    0.0000
#
#                    75%     max
# pregnancies    6.00000   17.00
# glucose      141.00000  199.00
# pressure      80.00000  122.00
# skin          36.00000   99.00
# insulin      190.00000  846.00
# bmi           36.60000   67.10
# pedigree       0.62625    2.42
# ...

# %% [markdown]
# ## Simple Imputer

# %%
from sklearn.impute import SimpleImputer

# %%
dataframe = diabetes_dataframe.copy()

# %%
dataframe.head()
# Out:
#    pregnancies  glucose  pressure  skin  insulin   bmi  pedigree  age  target
# 0            6    148.0      72.0  35.0      NaN  33.6     0.627   50       1
# 1            1     85.0      66.0  29.0      NaN  26.6     0.351   31       0
# 2            8    183.0      64.0   NaN      NaN  23.3     0.672   32       1
# 3            1     89.0      66.0  23.0     94.0  28.1     0.167   21       0
# 4            0    137.0      40.0  35.0    168.0  43.1     2.288   33       1

# %%
values = dataframe.values
values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
values[2]
# Out:
# array([  8.   , 183.   ,  64.   ,     nan,     nan,  23.3  ,   0.672,
#         32.   ,   1.   ])

# %%
# 1. Creación de los objetos
imputer = SimpleImputer(missing_values=nan, strategy='mean')

# 2. Ajustar a los datos
imputer.fit(values)

# 3. Transformación
transformed_values = imputer.transform(values)

#transformed_values = imputer.fit_transform(values)

# %%
transformed_values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
dataframe_transformed = pd.DataFrame(transformed_values)
dataframe_transformed.head()
# Out:
#      0      1     2         3           4     5      6     7    8
# 0  6.0  148.0  72.0  35.00000  155.548223  33.6  0.627  50.0  1.0
# 1  1.0   85.0  66.0  29.00000  155.548223  26.6  0.351  31.0  0.0
# 2  8.0  183.0  64.0  29.15342  155.548223  23.3  0.672  32.0  1.0
# 3  1.0   89.0  66.0  23.00000   94.000000  28.1  0.167  21.0  0.0
# 4  0.0  137.0  40.0  35.00000  168.000000  43.1  2.288  33.0  1.0

# %% [markdown]
# ## KNN Imputer

# %%
from sklearn.impute import KNNImputer

# %%
dataframe = diabetes_dataframe.copy()

# %%
values = dataframe.values

# %%
# 1. Crear el objeto
imputer = KNNImputer(n_neighbors=3, weights='distance', metric='nan_euclidean')

# 2. Ajustar a los datos
imputer.fit(values)

# 3. Transformación
transformed_values = imputer.transform(values)

#transformed_values = imputer.fit_transform(values)

# %%
values[2]
# Out:
# array([  8.   , 183.   ,  64.   ,     nan,     nan,  23.3  ,   0.672,
#         32.   ,   1.   ])

# %%
transformed_values[2]
# Out:
# array([  8.        , 183.        ,  64.        ,  30.0172571 ,
#        204.21952485,  23.3       ,   0.672     ,  32.        ,
#          1.        ])

# %%
dataframe_transformed = pd.DataFrame(transformed_values)
dataframe_transformed.head()
# Out:
#      0      1     2          3           4     5      6     7    8
# 0  6.0  148.0  72.0  35.000000  125.346137  33.6  0.627  50.0  1.0
# 1  1.0   85.0  66.0  29.000000   68.364757  26.6  0.351  31.0  0.0
# 2  8.0  183.0  64.0  30.017257  204.219525  23.3  0.672  32.0  1.0
# 3  1.0   89.0  66.0  23.000000   94.000000  28.1  0.167  21.0  0.0
# 4  0.0  137.0  40.0  35.000000  168.000000  43.1  2.288  33.0  1.0

# %%
dataframe_transformed.describe().T
# Out:
#    count        mean         std     min        25%         50%         75%  \
# 0  768.0    3.845052    3.369578   0.000   1.000000    3.000000    6.000000
# 1  768.0  121.568622   30.552828  44.000  99.000000  117.000000  141.000000
# 2  768.0   72.358055   12.228323  24.000  64.000000   72.000000   80.000000
# 3  768.0   29.100583    9.597608   7.000  22.300505   29.000000   35.024863
# 4  768.0  153.852447  101.437058  14.000  83.000000  130.428652  190.000000
# 5  768.0   32.430438    6.887934  18.200  27.500000   32.150000   36.600000
# 6  768.0    0.471876    0.331329   0.078   0.243750    0.372500    0.626250
# 7  768.0   33.240885   11.760232  21.000  24.000000   29.000000   41.000000
# 8  768.0    0.348958    0.476951   0.000   0.000000    0.000000    1.000000
#
#       max
# 0   17.00
# 1  199.00
# 2  122.00
# 3   99.00
# 4  846.00
# 5   67.10
# 6    2.42
# 7   81.00
# 8    1.00

# %%
dataframe.describe().T
# Out:
#              count        mean         std     min       25%       50%  \
# pregnancies  768.0    3.845052    3.369578   0.000   1.00000    3.0000
# glucose      763.0  121.686763   30.535641  44.000  99.00000  117.0000
# pressure     733.0   72.405184   12.382158  24.000  64.00000   72.0000
# skin         541.0   29.153420   10.476982   7.000  22.00000   29.0000
# insulin      394.0  155.548223  118.775855  14.000  76.25000  125.0000
# bmi          757.0   32.457464    6.924988  18.200  27.50000   32.3000
# pedigree     768.0    0.471876    0.331329   0.078   0.24375    0.3725
# age          768.0   33.240885   11.760232  21.000  24.00000   29.0000
# target       768.0    0.348958    0.476951   0.000   0.00000    0.0000
#
#                    75%     max
# pregnancies    6.00000   17.00
# glucose      141.00000  199.00
# pressure      80.00000  122.00
# skin          36.00000   99.00
# insulin      190.00000  846.00
# bmi           36.60000   67.10
# pedigree       0.62625    2.42
# ...

# %%
from math import sqrt

# %%
d1 = [6, 148, 72]
d2 = [1, 85, 66]
d3 = [8, 183, 64]

# %%
d1_d2 = sqrt((6-1)**2+(148-85)**2+(72-66)**2)
d1_d3 = sqrt((6-8)**2+(148-183)**2+(72-64)**2)

# %%
print(d1_d2, d1_d3)
# Out:
# 63.48228099241551 35.958309192730404

# %% [markdown]
# ## Interpolation

# %%
x = pd.Series([1.0, 4.0, nan, 16.0, 25.0, nan, 49.0, 64.0])

# %%
x.interpolate(method = 'zero', inplace = True)

# %%
x
# Out:
# 0     1.0
# 1     4.0
# 2     4.0
# 3    16.0
# 4    25.0
# 5    25.0
# 6    49.0
# 7    64.0
# dtype: float64
